# %%
from get_metadata import get_deployment_meta

# %%
params = {"FLOAT_SERIAL_NO__lt":'1500', 
    "PLATFORM_TYPE":'NAVIS_EBR',
    "deployment_fields":'FLOAT_SERIAL_NO,AOML_ID,PLATFORM_NUMBER,PLATFORM_TYPE,DEPLOYMENT_PLATFORM,sensors',
    "sensor_fields":'SENSOR,SENSOR_MAKER,SENSOR_MODEL'}

data = get_deployment_meta(params)

print(data)
# Out:
# [{'id': 15, 'ADD_DATE': '2021-05-17T19:32:41Z', 'AOML_ID': None, 'PLATFORM_NUMBER': None, 'FLOAT_SERIAL_NO': '1200', 'DEATH_DATE': None, 'WHOI_TAG': '121971', 'PURCHACE_ORDER': 'E120637', 'PLATFORM_MAKER': 'SBE', 'PLATFORM_TYPE': 'NAVIS_EBR', 'PLATFORM_TYPE_AOML': 'NAVISIR_TSOPJ1', 'PLATFORM_TYPE_WMO': '869', 'WMO_RECORDER_TYPE': '64', 'TRANS_SYSTEM': 'IRIDIUM', 'MODEM_TYPE': 'Civilian', 'MODEM_SERIAL_NO': 'e11hxx', 'START_DATE': None, 'START_DATE_QC': None, 'LAUNCH_DATE': None, 'LAUNCH_DATE_QC': None, 'LAUNCH_LATITUDE': None, 'LAUNCH_LONGITUDE': None, 'LAUNCH_POSITION_QC': None, 'INSTITUTION': 'WHOI', 'FUNDER': 'NOAA', 'PI_NAME': 'Nicholson, Wijffels', 'PI_ADDRESS': 'WHOI, Woods Hole, MA', 'ORIGIN_COUNTRY': 'USA', 'DEPLOYER': None, 'DEPLOYER_ADDRESS': None, 'DEPLOYMENT_PLATFORM': None, 'DEPLOYMENT_CRUISE_ID': None, 'DEPLOYMENT_REFERENCE_STATION_ID': None, 'DEPLOYMENT_MOB': None, 'DEPLOYMENT_PORT': None, 'FLOAT_CONTROLLER_SERIAL_NO': '1408', 'GPS_SERIAL_NO': '1qh045465', 'ROM_VERSION
# ...
